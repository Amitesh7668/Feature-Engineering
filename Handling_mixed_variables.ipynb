# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('datas.csv')

# %%
df.head()
# Out:
#   Cabin            Ticket number  Survived
# 0   NaN         A/5 21171      5         0
# 1   C85          PC 17599      3         1
# 2   NaN  STON/O2. 3101282      6         1
# 3  C123            113803      3         1
# 4   NaN            373450      A         0

# %%
df.isnull().sum()
# Out:
# Cabin       687
# Ticket        0
# number        0
# Survived      0
# dtype: int64

# %%
df.number.value_counts().plot(kind='bar');

# %% [markdown]
# ## extract numerical part

# %%
df['number_numerical'] = pd.to_numeric(df.number,errors='coerce',downcast='integer')

# %% [markdown]
# ## extract categorical part

# %%
df=df.drop('number',axis=1)

# %%
df['number_categorical']=np.where(df['number_numerical'].isnull(),df['number'],np.nan)

# %%
df.sample(10)
# Out:
#     Cabin     Ticket  Survived  number_numerical number_categorical
# 874   NaN  P/PP 3381         1               4.0                NaN
# 834   NaN       2223         0               6.0                NaN
# 354   NaN       2647         0               5.0                NaN
# 374   NaN     349909         0               1.0                NaN
# 627    D9      13502         1               5.0                NaN
# 79    NaN     364516         1               NaN                  A
# 569   NaN     350417         1               6.0                NaN
# 480   NaN    CA 2144         0               5.0                NaN
# 408   NaN     312992         0               NaN                  A
# 540   B22  WE/P 5735         1               2.0                NaN

# %%
df['number_categorical'].unique()
# Out:
# array([nan], dtype=object)

# %%
df.Cabin.unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
# capature numberical part
df['cabin_num']= df['Cabin'].str.extract('(\d+)')

# %%
# capature the first letter
df['cabin_cat']= df['Cabin'].str[0]

# %%
df.head()
# Out:
#   Cabin            Ticket  Survived  number_numerical number_categorical  \
# 0   NaN         A/5 21171         0               5.0                NaN
# 1   C85          PC 17599         1               3.0                NaN
# 2   NaN  STON/O2. 3101282         1               6.0                NaN
# 3  C123            113803         1               3.0                NaN
# 4   NaN            373450         0               NaN                  A
#
#   cabin_num cabin_cat
# 0       NaN       NaN
# 1        85         C
# 2       NaN       NaN
# 3       123         C
# 4       NaN       NaN

# %%
df=df.drop('Cabin',axis=1)

# %%
df.head()
# Out:
#              Ticket  Survived  number_numerical number_categorical cabin_num  \
# 0         A/5 21171         0               5.0                NaN       NaN
# 1          PC 17599         1               3.0                NaN        85
# 2  STON/O2. 3101282         1               6.0                NaN       NaN
# 3            113803         1               3.0                NaN       123
# 4            373450         0               NaN                  A       NaN
#
#   cabin_cat
# 0       NaN
# 1         C
# 2       NaN
# 3         C
# 4       NaN

# %%
df['cabin_cat'].value_counts().plot(kind='bar');

# %%
df.head()
# Out:
#              Ticket  Survived  number_numerical number_categorical cabin_num  \
# 0         A/5 21171         0               5.0                NaN       NaN
# 1          PC 17599         1               3.0                NaN        85
# 2  STON/O2. 3101282         1               6.0                NaN       NaN
# 3            113803         1               3.0                NaN       123
# 4            373450         0               NaN                  A       NaN
#
#   cabin_cat
# 0       NaN
# 1         C
# 2       NaN
# 3         C
# 4       NaN

# %%
df['Ticket'].unique()
# Out:
# array(['A/5 21171', 'PC 17599', 'STON/O2. 3101282', '113803', '373450',
#        '330877', '17463', '349909', '347742', '237736', 'PP 9549',
#        '113783', 'A/5. 2151', '347082', '350406', '248706', '382652',
#        '244373', '345763', '2649', '239865', '248698', '330923', '113788',
#        '347077', '2631', '19950', '330959', '349216', 'PC 17601',
#        'PC 17569', '335677', 'C.A. 24579', 'PC 17604', '113789', '2677',
#        'A./5. 2152', '345764', '2651', '7546', '11668', '349253',
#        'SC/Paris 2123', '330958', 'S.C./A.4. 23567', '370371', '14311',
#        '2662', '349237', '3101295', 'A/4. 39886', 'PC 17572', '2926',
#        '113509', '19947', 'C.A. 31026', '2697', 'C.A. 34651', 'CA 2144',
#        '2669', '113572', '36973', '347088', 'PC 17605', '2661',
#        'C.A. 29395', 'S.P. 3464', '3101281', '315151', 'C.A. 33111',
#        'S.O.C. 14879', '2680', '1601', '348123', '349208', '374746',
# ...

# %%
df['ticket_num']=df['Ticket'].apply(lambda x:x.split()[-1])

# %%
df.Ticket.value_counts()
# Out:
# 347082      7
# CA. 2343    7
# 1601        7
# 3101295     6
# CA 2144     6
#            ..
# 9234        1
# 19988       1
# 2693        1
# PC 17612    1
# 370376      1
# Name: Ticket, Length: 681, dtype: int64

# %%
# extract the first part of ticket as categorical
df['ticket_cate']=df['Ticket'].apply(lambda x:x.split()[0])
df['ticket_cate']= np.where(df['ticket_cate'].str.isdigit(),np.nan,df['ticket_cate'])

# %%
df['ticket_cate']
# Out:
# 0           A/5
# 1            PC
# 2      STON/O2.
# 3           NaN
# 4           NaN
#          ...
# 886         NaN
# 887         NaN
# 888       W./C.
# 889         NaN
# 890         NaN
# Name: ticket_cate, Length: 891, dtype: object

# %%
df.head()
# Out:
#              Ticket  Survived  number_numerical number_categorical cabin_num  \
# 0         A/5 21171         0               5.0                NaN       NaN
# 1          PC 17599         1               3.0                NaN        85
# 2  STON/O2. 3101282         1               6.0                NaN       NaN
# 3            113803         1               3.0                NaN       123
# 4            373450         0               NaN                  A       NaN
#
#   cabin_cat ticket_num ticket_ca        ticket_cat ticket_cate
# 0       NaN      21171       A/5         A/5 21171         A/5
# 1         C      17599        PC          PC 17599          PC
# 2       NaN    3101282  STON/O2.  STON/O2. 3101282    STON/O2.
# 3         C     113803    113803               NaN         NaN
# 4       NaN     373450    373450               NaN         NaN

# %%
df=df.drop('Ticket',axis=1)

# %%
df.head(30)
# Out:
#     Survived  number_numerical number_categorical cabin_num cabin_cat  \
# 0          0               5.0                NaN       NaN       NaN
# 1          1               3.0                NaN        85         C
# 2          1               6.0                NaN       NaN       NaN
# 3          1               3.0                NaN       123         C
# 4          0               NaN                  A       NaN       NaN
# 5          0               2.0                NaN       NaN       NaN
# 6          0               2.0                NaN        46         E
# 7          0               5.0                NaN       NaN       NaN
# 8          1               1.0                NaN       NaN       NaN
# 9          1               NaN                  A       NaN       NaN
# 10         1               1.0                NaN         6         G
# 11         1               1.0                NaN       103         C
# ...

# %%
df.ticket_cate.value_counts()
# Out:
# PC            60
# C.A.          27
# STON/O        12
# A/5           10
# W./C.          9
# CA.            8
# SOTON/O.Q.     8
# A/5.           7
# SOTON/OQ       7
# STON/O2.       6
# CA             6
# F.C.C.         5
# C              5
# SC/PARIS       5
# S.O.C.         5
# SC/Paris       4
# LINE           4
# A/4            3
# PP             3
# A/4.           3
# S.O./P.P.      3
# SC/AH          3
# A.5.           2
# A./5.          2
# P/PP           2
# WE/P           2
# SOTON/O2       2
# S.C./PARIS     2
# S.W./PP        1
# F.C.           1
# A/S            1
# SO/C           1
# W/C            1
# SC             1
# SCO/W          1
# SW/PP          1
# Fa             1
# S.O.P.         1
# S.C./A.4.      1
# A4.            1
# S.P.           1
# W.E.P.         1
# C.A./SOTON     1
# Name: ticket_cate, dtype: int64
