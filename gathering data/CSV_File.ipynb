# %% [markdown]
# # Importing pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # opening a local csv file

# %%
df=pd.read_csv('aug_train.csv',index_col=[0])

# %%
df.head()
# Out:
#                  city  city_development_index gender      relevent_experience  \
# enrollee_id
# 8949         city_103                   0.920   Male  Has relevent experience
# 29725         city_40                   0.776   Male   No relevent experience
# 11561         city_21                   0.624    NaN   No relevent experience
# 33241        city_115                   0.789    NaN   No relevent experience
# 666          city_162                   0.767   Male  Has relevent experience
#
#             enrolled_university education_level major_discipline experience  \
# enrollee_id
# 8949              no_enrollment        Graduate             STEM        >20
# 29725             no_enrollment        Graduate             STEM         15
# 11561          Full time course        Graduate             STEM          5
# 33241                       NaN        Graduate  Business Degree         <1
# 666               no_enrollment         Masters             STEM        >20
#
# ...

# %% [markdown]
# # opening a csv file from an url

# %%
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url, headers=headers)
data = StringIO(req.text)

pd.read_csv(data)
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %% [markdown]
# # sep parameter

# %%
pd.read_csv('movie_titles_metadata.tsv.txt',sep='\t',names=['Sno','movies_name','rating','votes','genres'])
# Out:
#                              Sno movies_name  rating     votes  \
# m0    10 things i hate about you        1999     6.9   62847.0
# m1    1492: conquest of paradise        1992     6.2   10421.0
# m2                    15 minutes        2001     6.1   25854.0
# m3         2001: a space odyssey        1968     8.4  163227.0
# m4                       48 hrs.        1982     6.9   22289.0
# ...                          ...         ...     ...       ...
# m612                    watchmen        2009     7.8  135229.0
# m613                         xxx        2002     5.6   53505.0
# m614                       x-men        2000     7.4  122149.0
# m615          young frankenstein        1974     8.0   57618.0
# m616                   zulu dawn        1979     6.4    1911.0
#
#                                                  genres
# m0                                 ['comedy' 'romance']
# m1          ['adventure' 'biography' 'drama' 'history']
# ...

# %%
pd.read_csv('movie_titles_metadata.tsv.txt',sep='\t',names=['Sno','movies_name','year','rating','votes','genres'])
# Out:
#       Sno                 movies_name  year  rating     votes  \
# 0      m0  10 things i hate about you  1999     6.9   62847.0
# 1      m1  1492: conquest of paradise  1992     6.2   10421.0
# 2      m2                  15 minutes  2001     6.1   25854.0
# 3      m3       2001: a space odyssey  1968     8.4  163227.0
# 4      m4                     48 hrs.  1982     6.9   22289.0
# ..    ...                         ...   ...     ...       ...
# 612  m612                    watchmen  2009     7.8  135229.0
# 613  m613                         xxx  2002     5.6   53505.0
# 614  m614                       x-men  2000     7.4  122149.0
# 615  m615          young frankenstein  1974     8.0   57618.0
# 616  m616                   zulu dawn  1979     6.4    1911.0
#
#                                                 genres
# 0                                 ['comedy' 'romance']
# 1          ['adventure' 'biography' 'drama' 'history']
# ...

# %% [markdown]
# # index_col

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %% [markdown]
# # header parameter

# %%
pd.read_csv('test.csv',header = 1,index_col=[1])
# Out:
#              0      city  city_development_index gender  \
# enrollee_id
# 29725        1   city_40                   0.776   Male
# 11561        2   city_21                   0.624    NaN
# 33241        3  city_115                   0.789    NaN
# 666          4  city_162                   0.767   Male
#
#                  relevent_experience enrolled_university education_level  \
# enrollee_id
# 29725         No relevent experience       no_enrollment        Graduate
# 11561         No relevent experience    Full time course        Graduate
# 33241         No relevent experience                 NaN        Graduate
# 666          Has relevent experience       no_enrollment         Masters
#
#             major_discipline experience company_size    company_type  \
# enrollee_id
# 29725                   STEM         15        50-99         Pvt Ltd
# 11561                   STEM          5          NaN             NaN
# ...

# %% [markdown]
# # usecols

# %%
pd.read_csv('aug_train.csv',usecols=['enrollee_id','gender','education_level'],index_col='enrollee_id')
# Out:
#             gender education_level
# enrollee_id
# 8949          Male        Graduate
# 29725         Male        Graduate
# 11561          NaN        Graduate
# 33241          NaN        Graduate
# 666           Male         Masters
# ...            ...             ...
# 7386          Male        Graduate
# 31398         Male        Graduate
# 24576         Male        Graduate
# 5756          Male     High School
# 23834          NaN  Primary School
#
# [19158 rows x 2 columns]

# %% [markdown]
# # encoding

# %%
pd.read_csv('zomato.csv',encoding='latin-1')
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %% [markdown]
# # skip bad lines

# %%
pd.read_csv('BX-Books.csv',sep=';',encoding='latin-1',error_bad_lines=False)
# Out:
# C:\Users\AmiteshOP\AppData\Local\Temp\ipykernel_21928\2796845451.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   pd.read_csv('BX-Books.csv',sep=';',encoding='latin-1',error_bad_lines=False)
# b'Skipping line 6452: expected 8 fields, saw 9\nSkipping line 43667: expected 8 fields, saw 10\nSkipping line 51751: expected 8 fields, saw 9\n'
# b'Skipping line 92038: expected 8 fields, saw 9\nSkipping line 104319: expected 8 fields, saw 9\nSkipping line 121768: expected 8 fields, saw 9\n'
# b'Skipping line 144058: expected 8 fields, saw 9\nSkipping line 150789: expected 8 fields, saw 9\nSkipping line 157128: expected 8 fields, saw 9\nSkipping line 180189: expected 8 fields, saw 9\nSkipping line 185738: expected 8 fields, saw 9\n'
# ...
