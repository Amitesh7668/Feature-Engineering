# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_style('darkgrid')

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
df=pd.read_csv('trai.csv')

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # Univariate Analysis

# %%
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# # Countplot

# %%
sns.countplot(df.Survived);

# %%
sns.countplot(df['Pclass']);

# %%
df.groupby('Pclass')['Fare'].mean()
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %%
sns.countplot(df.Sex);

# %%
sns.countplot(df.Embarked);

# %% [markdown]
# # Pie

# %%
df['Survived'].value_counts().plot(kind='pie',
                                   explode=[0.0,0.1],
                                   autopct='%1.2f%%');

# %%
df['Pclass'].value_counts().plot(kind='pie',
                                   explode=[0.0,0.01,0.1],
                                   autopct='%1.2f%%');

# %%
df['Sex'].value_counts().plot(kind='pie',
                                   explode=[0.0,0.03],
                                   autopct='%1.2f%%');

# %% [markdown]
# # Histogram

# %%
plt.hist(df['Age'],bins=[0,20,40,60,80]);

# %% [markdown]
# # Distplot

# %%
sns.distplot(df.Age);

# %% [markdown]
# # Boxplot

# %%
 sns.boxplot(df['Fare']);

# %%
sns.boxplot(df['Age']);

# %% [markdown]
# # Bivariate & Multivarite  Analysis

# %%
tip = sns.load_dataset('tips')

# %%
flight = sns.load_dataset('flights')
iris = sns.load_dataset('iris')

# %% [markdown]
# # Scatterplot (Numerical - Numerical)

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## Relation b/w total_bill and tip which gender and what they are smoking or not

# %%
sns.scatterplot(tip['total_bill'],tip['tip'],hue=tip['sex'],style=tip['smoker']);

# %% [markdown]
# # Bar Plot (Numerical - Categorical)

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %% [markdown]
# # Pclass Average Age Distribution

# %%
sns.barplot(x='Pclass',y='Age',data=df);

# %% [markdown]
# # Pclass Average Fare distribution

# %%
sns.barplot(x='Pclass',y='Fare',data=df);

# %% [markdown]
# # Distribution of Gender in Average Fare & Pclass

# %%
sns.barplot(x='Pclass',y='Fare',data=df,hue='Sex');

# %% [markdown]
# ## Distribution of Gender in Average Age & Pclass

# %%
sns.barplot(x='Pclass',y='Age',data=df,hue='Sex');

# %% [markdown]
# # Box Plot (Numerical - Categorical)

# %%
sns.boxplot('Sex','Age',data=df,hue='Survived');

# %% [markdown]
# # Distplot (Numerical - Categorical)
